# %% [markdown]
# Learning Polynomials
# ==================
#
# We will try to learn some polynomial with increasing degree, we note that:
#
# - polynomials can be accurately learned with small word sets (`learn_resolution=2`)
# - the number of states of the resulting WFA is the degree + 1

# %%
# %matplotlib notebook

from pyautospec import FunctionWfa

# %%
# learn 3x + 2 in the [-10,+10] interval
p1_a = FunctionWfa(lambda x: 3*x + 1, x0=-10.0, x1=10.0, learn_resolution=2)

p1_a
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# WFA(states=2) <function <lambda> at 0x6d69f58a9d80>: [-10.00,10.00] → R

# %%
p1_a.model.diagram()

# %%
p1_a.comparison_chart()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# learn 3x^2 + 2x + 2 in the [-10,+10] interval
p2_a = FunctionWfa(lambda x: 3*x**2 + 2*x + 2, x0=-10.0, x1=10.0, learn_resolution=2)

p2_a
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# WFA(states=3) <function <lambda> at 0x6d69e8782710>: [-10.00,10.00] → R

# %%
p2_a.model.diagram()

# %%
p2_a.comparison_chart()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# learn 5x^3 - 3x^2 + 2x + 2 in the [-10,+10] interval
p3_a = FunctionWfa(lambda x: 5*x**3 - 3*x**2 + 2*x + 2, x0=-10.0, x1=10.0, learn_resolution=2)

p3_a
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# WFA(states=4) <function <lambda> at 0x6d69e865f880>: [-10.00,10.00] → R

# %%
p3_a.model.diagram()

# %%
p3_a.comparison_chart()
# Out:
# <img src="data:image/png;base64,..." width="640">
